# %% [markdown]
# ### Data Profiling
# ###### Data Analysis before creating Data Pipeline

# %%
path_to_file = "/home/developer/Coding/assignments/data_engineer_assessment/data/fake_property_data.json"

import json
import pandas as pd


df = pd.read_json(path_to_file)

# %%
from pathlib import Path
import json

# path to file
# 
# # read json
with open(path_to_file, encoding='utf-8') as f:
    data = json.loads(f.read())

df = pd.json_normalize(data)

# %%
df.head(1)
# Out:
#                                       Property_Title  \
# 0  875 Davis Overpass Suite 394, South Kathrynsid...
#
#                                              Address Reviewed_Status  \
# 0  875 Davis Overpass Suite 394, South Kathrynsid...
#
#   Most_Recent_Status    Source   Market Occupancy Flood  \
# 0             Closed  Internal  Chicago      None  None
#
#                  Street_Address               City  ...  Longitude  \
# 0  875 Davis Overpass Suite 394  South Kathrynside  ... -81.853842
#
#   Subdivision Taxes Selling_Reason Seller_Retained_Broker  Final_Reviewer  \
# 0      Manors  6389     Downsizing                   None    Jason Miller
#
#    School_Average                                          Valuation  \
# 0            9.09  [{'List_Price': 93528, 'Previous_Rent': 1699, ...
#
#                                                  HOA  \
# 0  [{'HOA': 460, 'HOA_Flag': 'No'}, {'HOA': 476, ...
#
#                                                Rehab
# ...

# %%
# datatypes of each column
df.dtypes
# Out:
# Property_Title             object
# Address                    object
# Reviewed_Status            object
# Most_Recent_Status         object
# Source                     object
# Market                     object
# Occupancy                  object
# Flood                      object
# Street_Address             object
# City                       object
# State                      object
# Zip                        object
# Property_Type              object
# Highway                    object
# Train                      object
# Tax_Rate                  float64
# SQFT_Basement               int64
# HTW                        object
# Pool                       object
# Commercial                 object
# Water                      object
# Sewage                     object
# Year_Built                  int64
# SQFT_MU                     int64
# SQFT_Total                  int64
# Parking                    object
# Bed                         int64
# ...

# %% [markdown]
# #### Understanding each column data
#
# Aim here is to find datatype os each attribute and convert them to appropriate type
# and try to make lookup table is any. So that it takes less storage.

# %%
for i in list(df.columns):
    try:
        print("Attribute name = ",i)
        print("Unique values count = ",df[i].nunique())
        print("Attribute data type =  ",df[i].dtype)
        if df[i].nunique() < 100:
            print("Unique Values = ",df[i].unique())
        print("_____"* 50)
    
    except TypeError:
        print(" Skipping... ",i)
# Out:
# Attribute name =  Property_Title
# Unique values count =  10000
# Attribute data type =   object
# __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# Attribute name =  Address
# Unique values count =  10000
# Attribute data type =   object
# __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# Attribute name =  Reviewed_Status
# Unique values count =  10
# Attribute data type =   object
# Unique Values =  [' ' 'Reviewed' 'Null' ' Closed' 'Closed' 'New' 'Cancelled' 'Neww'
#  'Accepted Offer' 'Offered']
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Property_Title          10000 non-null  object
#  1   Address                 10000 non-null  object
#  2   Reviewed_Status         10000 non-null  object
#  3   Most_Recent_Status      10000 non-null  object
#  4   Source                  10000 non-null  object
#  5   Market                  10000 non-null  object
#  6   Occupancy               6718 non-null   object
#  7   Flood                   6591 non-null   object
#  8   Street_Address          10000 non-null  object
#  9   City                    10000 non-null  object
#  10  State                   10000 non-null  object
#  11  Zip                     10000 non-null  object
#  12  Property_Type           10000 non-null  object
#  13  Highway                 6602 non-null   object
# ...

# %%
df.Property_Title.duplicated().sum()
# Out:
# np.int64(0)

# %%
# from ydata_profiling import ProfileReport

# profile = ProfileReport(df, title="Data Profile Report")
# profile.to_file("report.html")
